# %%
#https://www.youtube.com/watch?v=SstuvS-tVc0
#https://github.com/gordicaleksa/get-started-with-JAX/blob/main/Tutorial_1_JAX_Zero2Hero_Colab.ipynb

# %%
import jax.numpy as jnp
import matplotlib.pyplot as plt

# %%
plt.plot(jnp.sin(jnp.linspace(0, 10, 100)))
# Out:
# 2024-08-24 15:26:14.606115: W external/xla/xla/service/gpu/nvptx_compiler.cc:836] The NVIDIA driver's CUDA version is 12.2 which is older than the PTX compiler version (12.6.20). Because the driver is older than the PTX compiler version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
